# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/NLP\ Project/nmrs
# Out:
# /content/gdrive/MyDrive/NLP Project/nmrs

# %%
# %cd /content/gdrive/MyDrive/2022-2023/6.8611/NLP Project/nmrs
# Out:
# /content/gdrive/.shortcut-targets-by-id/1S2xwZOkYkBeaAxy88aECjXoO-wmDboU5/NLP Project/nmrs

# %%
# ! git clone https://github.com/yflyl613/NewsRecommendation.git
# Out:
# Cloning into 'NewsRecommendation'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 24 (delta 4), reused 24 (delta 4), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
# %cd NewsRecommendation/
# Out:
# /content/gdrive/MyDrive/NLP Project/nmrs/NewsRecommendation

# %%
# ! git pull
# Out:
# Already up to date.

# %%
# %cd src/
# Out:
# /content/gdrive/MyDrive/NLP Project/nmrs/NewsRecommendation/src

# %%
# %cd ../data/

# !wget https://nlp.stanford.edu/data/glove.840B.300d.zip
# !unzip glove.840B.300d.zip
# Out:
# /content/gdrive/.shortcut-targets-by-id/1S2xwZOkYkBeaAxy88aECjXoO-wmDboU5/NLP Project/nmrs/NewsRecommendation/data
# --2022-12-05 22:07:58--  https://nlp.stanford.edu/data/glove.840B.300d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip [following]
# --2022-12-05 22:07:58--  https://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2176768927 (2.0G) [application/zip]
# Saving to: ‘glove.840B.300d.zip’
#
# glove.840B.300d.zip 100%[===================>]   2.03G  5.59MB/s    in 7m 21s
#
# ...

# %%
# %cd ../src/
# Out:
# /content/gdrive/.shortcut-targets-by-id/1S2xwZOkYkBeaAxy88aECjXoO-wmDboU5/NLP Project/nmrs/NewsRecommendation/src

# %%
# !pip install nltkimport nltk
import nltk

nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement nltkimport (from versions: none)
# ERROR: No matching distribution found for nltkimport
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 30.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 17.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 55.9 MB/s
# ...

# %%
# !bash demo.sh train
# Out:
# INFO:root:args[batch_size]=32
# [INFO 2022-12-14 15:23:22,852] args[batch_size]=32
# INFO:root:args[category_emb_dim]=100
# [INFO 2022-12-14 15:23:22,852] args[category_emb_dim]=100
# INFO:root:args[drop_rate]=0.2
# [INFO 2022-12-14 15:23:22,852] args[drop_rate]=0.2
# INFO:root:args[enable_gpu]=True
# [INFO 2022-12-14 15:23:22,852] args[enable_gpu]=True
# INFO:root:args[epochs]=5
# [INFO 2022-12-14 15:23:22,852] args[epochs]=5
# INFO:root:args[filter_num]=3
# [INFO 2022-12-14 15:23:22,852] args[filter_num]=3
# INFO:root:args[freeze_embedding]=False
# [INFO 2022-12-14 15:23:22,852] args[freeze_embedding]=False
# INFO:root:args[glove_embedding_path]=../data/glove.840B.300d.txt
# [INFO 2022-12-14 15:23:22,852] args[glove_embedding_path]=../data/glove.840B.300d.txt
# INFO:root:args[load_ckpt_name]=None
# [INFO 2022-12-14 15:23:22,852] args[load_ckpt_name]=None
# INFO:root:args[log_steps]=100
# [INFO 2022-12-14 15:23:22,852] args[log_steps]=100
# INFO:root:args[lr]=0.0003
# ...

# %%
# !bash demo.sh test epoch-5.pt
# Out:
# INFO:root:args[batch_size]=128
# [INFO 2022-12-14 16:09:44,269] args[batch_size]=128
# INFO:root:args[category_emb_dim]=100
# [INFO 2022-12-14 16:09:44,269] args[category_emb_dim]=100
# INFO:root:args[drop_rate]=0.2
# [INFO 2022-12-14 16:09:44,269] args[drop_rate]=0.2
# INFO:root:args[enable_gpu]=True
# [INFO 2022-12-14 16:09:44,269] args[enable_gpu]=True
# INFO:root:args[epochs]=1
# [INFO 2022-12-14 16:09:44,269] args[epochs]=1
# INFO:root:args[filter_num]=3
# [INFO 2022-12-14 16:09:44,269] args[filter_num]=3
# INFO:root:args[freeze_embedding]=False
# [INFO 2022-12-14 16:09:44,269] args[freeze_embedding]=False
# INFO:root:args[glove_embedding_path]=../data/glove.840B.300d.txt
# [INFO 2022-12-14 16:09:44,269] args[glove_embedding_path]=../data/glove.840B.300d.txt
# INFO:root:args[load_ckpt_name]=epoch-5.pt
# [INFO 2022-12-14 16:09:44,269] args[load_ckpt_name]=epoch-5.pt
# INFO:root:args[log_steps]=100
# [INFO 2022-12-14 16:09:44,270] args[log_steps]=100
# INFO:root:args[lr]=0.0001
# ...
